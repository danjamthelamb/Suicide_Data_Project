# %%
import pandas as pd

# %%
file_path = "..\Data_Files\suicide-lghc-indicator-21\suicide-lghc-indicator-21.csv"
suicide_raw = pd.read_csv(file_path)
suicide_df = pd.DataFrame(suicide_raw)
suicide_df
# Out:
#      Indicator   Geography       Year Strata Strata Name  Numerator  \
# 0      Suicide  CALIFORNIA       2000    Sex      Female        682
# 1      Suicide  CALIFORNIA       2000    Sex        Male       2431
# 2      Suicide  CALIFORNIA       2000    Sex       Total       3113
# 3      Suicide  CALIFORNIA       2001    Sex      Female        685
# 4      Suicide  CALIFORNIA       2001    Sex        Male       2571
# ...        ...         ...        ...    ...         ...        ...
# 1399   Suicide       Butte  2015-2017    Sex       Total        128
# 1400   Suicide  Santa Cruz  2015-2017    Sex       Total        136
# 1401   Suicide      Sonoma  2015-2017    Sex       Total        205
# 1402   Suicide     Trinity  2015-2017    Sex       Total         16
# 1403   Suicide      Sutter  2015-2017    Sex       Total         42
#
#       Denominator    Rate  Age Adjusted Rate
# 0        17080000   3.993              4.067
# 1        16920000  14.370             15.890
# 2        34000000   9.156              9.564
# 3        17340000   3.950              4.005
# 4        17170000  14.970             16.410
# ...           ...     ...                ...
# 1399       676000  18.940             18.310
# 1400       829300  16.400             15.740
# 1401      1512000  13.550             12.190
# 1402        40490  39.510             43.870
# 1403       294800  14.250             13.870
#
# [1404 rows x 9 columns]

# %% [markdown]
# # California

# %%
# Isolates all rows containing California.

cont_cali = suicide_df['Geography'] == 'CALIFORNIA'
suicide_cali = suicide_df[cont_cali]
suicide_cali = suicide_cali.reset_index()
suicide_cali = suicide_cali.drop(columns=['index'])
suicide_cali
# Out:
#     Indicator   Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide  CALIFORNIA       2000    Sex      Female        682
# 1     Suicide  CALIFORNIA       2000    Sex        Male       2431
# 2     Suicide  CALIFORNIA       2000    Sex       Total       3113
# 3     Suicide  CALIFORNIA       2001    Sex      Female        685
# 4     Suicide  CALIFORNIA       2001    Sex        Male       2571
# ..        ...         ...        ...    ...         ...        ...
# 109   Suicide  CALIFORNIA  2012-2014    Sex        Male       9163
# 110   Suicide  CALIFORNIA  2012-2014    Sex       Total      11870
# 111   Suicide  CALIFORNIA  2015-2017    Sex      Female       2916
# 112   Suicide  CALIFORNIA  2015-2017    Sex        Male       9642
# 113   Suicide  CALIFORNIA  2015-2017    Sex       Total      12560
#
#      Denominator    Rate  Age Adjusted Rate
# 0       17080000   3.993              4.067
# 1       16920000  14.370             15.890
# 2       34000000   9.156              9.564
# 3       17340000   3.950              4.005
# 4       17170000  14.970             16.410
# ..           ...     ...                ...
# 109     57270000  16.000             16.090
# 110    115200000  10.310             10.050
# 111     59330000   4.915              4.681
# 112     58780000  16.400             16.200
# 113    118100000  10.630             10.260
#
# [114 rows x 9 columns]

# %% [markdown]
# ## California - Sex

# %%
# Isolates california wide suicides by sex.

cali_bysex = suicide_cali['Strata'] == 'Sex'
suicide_cali_sex = suicide_cali[cali_bysex]
suicide_cali_sex = suicide_cali_sex.reset_index()
suicide_cali_sex = suicide_cali_sex.drop(columns=['index'])
suicide_cali_sex
# Out:
#    Indicator   Geography       Year Strata Strata Name  Numerator  \
# 0    Suicide  CALIFORNIA       2000    Sex      Female        682
# 1    Suicide  CALIFORNIA       2000    Sex        Male       2431
# 2    Suicide  CALIFORNIA       2000    Sex       Total       3113
# 3    Suicide  CALIFORNIA       2001    Sex      Female        685
# 4    Suicide  CALIFORNIA       2001    Sex        Male       2571
# ..       ...         ...        ...    ...         ...        ...
# 67   Suicide  CALIFORNIA  2012-2014    Sex        Male       9163
# 68   Suicide  CALIFORNIA  2012-2014    Sex       Total      11870
# 69   Suicide  CALIFORNIA  2015-2017    Sex      Female       2916
# 70   Suicide  CALIFORNIA  2015-2017    Sex        Male       9642
# 71   Suicide  CALIFORNIA  2015-2017    Sex       Total      12560
#
#     Denominator    Rate  Age Adjusted Rate
# 0      17080000   3.993              4.067
# 1      16920000  14.370             15.890
# 2      34000000   9.156              9.564
# 3      17340000   3.950              4.005
# 4      17170000  14.970             16.410
# ..          ...     ...                ...
# 67     57270000  16.000             16.090
# 68    115200000  10.310             10.050
# 69     59330000   4.915              4.681
# 70     58780000  16.400             16.200
# 71    118100000  10.630             10.260
#
# [72 rows x 9 columns]

# %% [markdown]
# ## California - Race

# %%
# Isolates california wide suicides by race.

cali_byrace = suicide_cali['Strata'] == 'Race/Ethnicity'
suicide_cali_race = suicide_cali[cali_byrace]
suicide_cali_race = suicide_cali_race.reset_index()
suicide_cali_race = suicide_cali_race.drop(columns=['index'])
suicide_cali_race
# Out:
#    Indicator   Geography       Year          Strata Strata Name  Numerator  \
# 0    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity     AIAN-NH         41
# 1    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity    Asian-NH        658
# 2    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity    Black-NH        430
# 3    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity        Hisp       1380
# 4    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity    Multi-NH         41
# 5    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity     NHPI-NH         26
# 6    Suicide  CALIFORNIA  2000-2002  Race/Ethnicity    White-NH       6990
# 7    Suicide  CALIFORNIA  2003-2005  Race/Ethnicity     AIAN-NH         46
# 8    Suicide  CALIFORNIA  2003-2005  Race/Ethnicity    Asian-NH        719
# 9    Suicide  CALIFORNIA  2003-2005  Race/Ethnicity    Black-NH        388
# 10   Suicide  CALIFORNIA  2003-2005  Race/Ethnicity        Hisp       1563
# 11   Suicide  CALIFORNIA  2003-2005  Race/Ethnicity    Multi-NH         88
# 12   Suicide  CALIFORNIA  2003-2005  Race/Ethnicity     NHPI-NH         33
# 13   Suicide  CALIFORNIA  2003-2005  Race/Ethnicity    White-NH       7027
# 14   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity     AIAN-NH         47
# 15   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity    Asian-NH        807
# 16   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity    Black-NH        432
# 17   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity        Hisp       1604
# 18   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity    Multi-NH        131
# 19   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity     NHPI-NH         30
# 20   Suicide  CALIFORNIA  2006-2008  Race/Ethnicity    White-NH       7349
# 21   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity     AIAN-NH         59
# 22   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity    Asian-NH        935
# 23   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity    Black-NH        435
# 24   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity        Hisp       1857
# 25   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity    Multi-NH        175
# 26   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity     NHPI-NH         42
# 27   Suicide  CALIFORNIA  2009-2011  Race/Ethnicity    White-NH       7937
# 28   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity     AIAN-NH         60
# 29   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity    Asian-NH        920
# 30   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity    Black-NH        428
# 31   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity        Hisp       1991
# 32   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity    Multi-NH        242
# 33   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity     NHPI-NH         41
# 34   Suicide  CALIFORNIA  2012-2014  Race/Ethnicity    White-NH       8154
# 35   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity     AIAN-NH         74
# 36   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity    Asian-NH       1072
# 37   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity    Black-NH        456
# 38   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity        Hisp       2482
# 39   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity    Multi-NH        261
# 40   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity     NHPI-NH         40
# 41   Suicide  CALIFORNIA  2015-2017  Race/Ethnicity    White-NH       8139
#
#     Denominator    Rate  Age Adjusted Rate
# 0        531100   7.719              7.810
# 1      11980000   5.493              5.585
# 2       6624000   6.491              6.656
# 3      34400000   4.012              4.684
# 4       1964000   2.088              2.184
# 5        342600   7.590              7.165
# 6      47610000  14.680             13.300
# 7        518900   8.865              8.860
# 8      12740000   5.642              5.564
# 9       6673000   5.814              5.864
# 10     37200000   4.202              4.814
# 11      2247000   3.917              4.562
# 12       361100   9.139             10.120
# 13     47380000  14.830             13.300
# 14       510300   9.211              8.825
# 15     13420000   6.013              5.814
# 16      6650000   6.496              6.369
# 17     39550000   4.055              4.562
# 18      2477000   5.289              7.063
# 19       376800   7.961              8.064
# 20     46670000  15.750             13.770
# 21       502900  11.730             11.450
# 22     14330000   6.523              6.094
# 23      6606000   6.584              6.414
# 24     42170000   4.404              4.745
# 25      2752000   6.360              8.303
# 26       398900  10.530              9.709
# 27     45330000  17.510             15.020
# 28       512900  11.700             11.540
# 29     15060000   6.108              5.722
# 30      6680000   6.407              6.193
# 31     44310000   4.494              4.713
# 32      2993000   8.085              9.462
# 33       418200   9.804              9.832
# 34     45180000  18.050             15.430
# 35       523600  14.130             13.680
# 36     15730000   6.813              6.433
# 37      6755000   6.751              6.548
# 38     46350000   5.355              5.506
# 39      3204000   8.146              9.573
# 40       435000   9.196              8.534
# 41     45010000  18.080             15.580

# %% [markdown]
# # All Counties

# %%
# Isolates all rows without California in 'Geography'.

all_counties = suicide_df['Geography'] != 'CALIFORNIA'
suicide_counties = suicide_df[all_counties]
suicide_counties = suicide_counties.reset_index()
suicide_counties = suicide_counties.drop(columns=['index'])
suicide_counties
# Out:
#      Indicator   Geography       Year          Strata Strata Name  Numerator  \
# 0      Suicide     Alameda  2000-2002  Race/Ethnicity    Asian-NH         47
# 1      Suicide     Alameda  2000-2002  Race/Ethnicity    Black-NH         34
# 2      Suicide     Alameda  2000-2002  Race/Ethnicity        Hisp         31
# 3      Suicide     Alameda  2000-2002  Race/Ethnicity    White-NH        234
# 4      Suicide     Alameda  2003-2005  Race/Ethnicity    Asian-NH         46
# ...        ...         ...        ...             ...         ...        ...
# 1285   Suicide       Butte  2015-2017             Sex       Total        128
# 1286   Suicide  Santa Cruz  2015-2017             Sex       Total        136
# 1287   Suicide      Sonoma  2015-2017             Sex       Total        205
# 1288   Suicide     Trinity  2015-2017             Sex       Total         16
# 1289   Suicide      Sutter  2015-2017             Sex       Total         42
#
#       Denominator    Rate  Age Adjusted Rate
# 0          970100   4.845              4.940
# 1          622600   5.461              5.596
# 2          858900   3.609              4.775
# 3         1757000  13.320             11.890
# 4         1028000   4.473              4.353
# ...           ...     ...                ...
# 1285       676000  18.940             18.310
# 1286       829300  16.400             15.740
# 1287      1512000  13.550             12.190
# 1288        40490  39.510             43.870
# 1289       294800  14.250             13.870
#
# [1290 rows x 9 columns]

# %% [markdown]
# ## Counties - Sex

# %%
county_bysex = suicide_counties['Strata'] == 'Sex'
suicide_county_sex = suicide_counties[county_bysex]
suicide_county_sex = suicide_county_sex.reset_index()
suicide_county_sex = suicide_county_sex.drop(columns=['index'])
suicide_county_sex
# Out:
#     Indicator      Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide  San Francisco  2000-2002    Sex      Female         67
# 1     Suicide      El Dorado  2000-2002    Sex      Female         13
# 2     Suicide         Fresno  2000-2002    Sex      Female         36
# 3     Suicide           Kern  2000-2002    Sex      Female         32
# 4     Suicide      Riverside  2000-2002    Sex      Female        111
# ..        ...            ...        ...    ...         ...        ...
# 707   Suicide          Butte  2015-2017    Sex       Total        128
# 708   Suicide     Santa Cruz  2015-2017    Sex       Total        136
# 709   Suicide         Sonoma  2015-2017    Sex       Total        205
# 710   Suicide        Trinity  2015-2017    Sex       Total         16
# 711   Suicide         Sutter  2015-2017    Sex       Total         42
#
#      Denominator    Rate  Age Adjusted Rate
# 0        1153000   5.809              4.898
# 1         242700   5.357              5.355
# 2        1222000   2.946              3.158
# 3         991600   3.227              3.476
# 4        2444000   4.542              4.754
# ..           ...     ...                ...
# 707       676000  18.940             18.310
# 708       829300  16.400             15.740
# 709      1512000  13.550             12.190
# 710        40490  39.510             43.870
# 711       294800  14.250             13.870
#
# [712 rows x 9 columns]

# %% [markdown]
# ### Counties - Sex - "2000-2002"

# %%
count_sex_by00_02 = suicide_county_sex['Year'] == '2000-2002'
count_sex_00_02 = suicide_county_sex[count_sex_by00_02]
count_sex_00_02 = count_sex_00_02.reset_index()
count_sex_00_02 = count_sex_00_02.drop(columns=['index'])
count_sex_00_02
# Out:
#     Indicator      Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide  San Francisco  2000-2002    Sex      Female         67
# 1     Suicide      El Dorado  2000-2002    Sex      Female         13
# 2     Suicide         Fresno  2000-2002    Sex      Female         36
# 3     Suicide           Kern  2000-2002    Sex      Female         32
# 4     Suicide      Riverside  2000-2002    Sex      Female        111
# ..        ...            ...        ...    ...         ...        ...
# 106   Suicide          Kings  2000-2002    Sex       Total         32
# 107   Suicide     Sacramento  2000-2002    Sex       Total        412
# 108   Suicide      Del Norte  2000-2002    Sex       Total         19
# 109   Suicide       Imperial  2000-2002    Sex       Total         26
# 110   Suicide      San Diego  2000-2002    Sex       Total        955
#
#      Denominator    Rate  Age Adjusted Rate
# 0        1153000   5.809              4.898
# 1         242700   5.357              5.355
# 2        1222000   2.946              3.158
# 3         991600   3.227              3.476
# 4        2444000   4.542              4.754
# ..           ...     ...                ...
# 106       396900   8.063              8.313
# 107      3790000  10.870             11.160
# 108        82470  23.040             22.440
# 109       435100   5.976              6.409
# 110      8609000  11.090             11.420
#
# [111 rows x 9 columns]

# %% [markdown]
# ### Counties - Sex - "2003-2005"

# %%
count_sex_by03_05 = suicide_county_sex['Year'] == '2003-2005'
count_sex_03_05 = suicide_county_sex[count_sex_by03_05]
count_sex_03_05 = count_sex_03_05.reset_index()
count_sex_03_05 = count_sex_03_05.drop(columns=['index'])
count_sex_03_05
# Out:
#     Indicator    Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide      Ventura  2003-2005    Sex      Female         58
# 1     Suicide       Solano  2003-2005    Sex      Female         18
# 2     Suicide        Marin  2003-2005    Sex      Female         31
# 3     Suicide  Los Angeles  2003-2005    Sex      Female        473
# 4     Suicide       Orange  2003-2005    Sex      Female        190
# ..        ...          ...        ...    ...         ...        ...
# 112   Suicide         Yolo  2003-2005    Sex       Total         41
# 113   Suicide     Tuolumne  2003-2005    Sex       Total         40
# 114   Suicide  San Joaquin  2003-2005    Sex       Total        137
# 115   Suicide       Placer  2003-2005    Sex       Total        104
# 116   Suicide         Lake  2003-2005    Sex       Total         33
#
#      Denominator    Rate  Age Adjusted Rate
# 0        1196000   4.851              4.833
# 1         613900   2.932              2.909
# 2         375200   8.262              7.632
# 3       14910000   3.173              3.216
# 4        4465000   4.256              4.266
# ..           ...     ...                ...
# 112       555400   7.382              8.004
# 113       169300  23.630             22.060
# 114      1911000   7.168              7.652
# 115       906100  11.480             11.290
# 116       187700  17.580             16.910
#
# [117 rows x 9 columns]

# %% [markdown]
# ### Counties - Sex - "2006-2008"

# %%
count_sex_by06_08 = suicide_county_sex['Year'] == '2006-2008'
count_sex_06_08 = suicide_county_sex[count_sex_by06_08]
count_sex_06_08 = count_sex_06_08.reset_index()
count_sex_06_08 = count_sex_06_08.drop(columns=['index'])
count_sex_06_08
# Out:
#     Indicator    Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide     Humboldt  2006-2008    Sex      Female         26
# 1     Suicide  Santa Clara  2006-2008    Sex      Female        116
# 2     Suicide         Kern  2006-2008    Sex      Female         47
# 3     Suicide    El Dorado  2006-2008    Sex      Female         19
# 4     Suicide        Butte  2006-2008    Sex      Female         18
# ..        ...          ...        ...    ...         ...        ...
# 113   Suicide     Mariposa  2006-2008    Sex       Total         13
# 114   Suicide       Tulare  2006-2008    Sex       Total        111
# 115   Suicide     Humboldt  2006-2008    Sex       Total         87
# 116   Suicide     Tuolumne  2006-2008    Sex       Total         38
# 117   Suicide         Yolo  2006-2008    Sex       Total         63
#
#      Denominator    Rate  Age Adjusted Rate
# 0         199300  13.040             12.270
# 1        2587000   4.484              4.389
# 2        1168000   4.022              4.347
# 3         265600   7.153              6.650
# 4         330000   5.454              5.890
# ..           ...     ...                ...
# 113        55010  23.630             21.420
# 114      1271000   8.732              9.849
# 115       398100  21.850             20.590
# 116       168800  22.520             19.930
# 117       583300  10.800             11.210
#
# [118 rows x 9 columns]

# %% [markdown]
# ### Counties - Sex - "2009-2011"

# %%
count_sex_by09_11 = suicide_county_sex['Year'] == '2009-2011'
count_sex_09_11 = suicide_county_sex[count_sex_by09_11]
count_sex_09_11 = count_sex_09_11.reset_index()
count_sex_09_11 = count_sex_09_11.drop(columns=['index'])
count_sex_09_11
# Out:
#     Indicator       Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide          Orange  2009-2011    Sex      Female        207
# 1     Suicide          Madera  2009-2011    Sex      Female         16
# 2     Suicide          Solano  2009-2011    Sex      Female         37
# 3     Suicide          Fresno  2009-2011    Sex      Female         58
# 4     Suicide            Lake  2009-2011    Sex      Female         13
# ..        ...             ...        ...    ...         ...        ...
# 120   Suicide          Tehama  2009-2011    Sex       Total         33
# 121   Suicide          Solano  2009-2011    Sex       Total        161
# 122   Suicide  San Bernardino  2009-2011    Sex       Total        637
# 123   Suicide     Santa Clara  2009-2011    Sex       Total        451
# 124   Suicide      Santa Cruz  2009-2011    Sex       Total        108
#
#      Denominator    Rate  Age Adjusted Rate
# 0        4576000   4.524              4.386
# 1         234000   6.837              6.971
# 2         620600   5.962              6.174
# 3        1400000   4.142              4.346
# 4          96680  13.450             12.790
# ..           ...     ...                ...
# 120       190200  17.350             16.360
# 121      1240000  12.990             12.850
# 122      6131000  10.390             10.860
# 123      5379000   8.384              8.196
# 124       789400  13.680             13.470
#
# [125 rows x 9 columns]

# %% [markdown]
# ### Counties - Sex - "2012-2014"

# %%
count_sex_by12_14 = suicide_county_sex['Year'] == '2012-2014'
count_sex_12_14 = suicide_county_sex[count_sex_by12_14]
count_sex_12_14 = count_sex_12_14.reset_index()
count_sex_12_14 = count_sex_12_14.drop(columns=['index'])
count_sex_12_14
# Out:
#     Indicator       Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide  San Bernardino  2012-2014    Sex      Female        103
# 1     Suicide          Merced  2012-2014    Sex      Female         18
# 2     Suicide       Mendocino  2012-2014    Sex      Female         13
# 3     Suicide          Nevada  2012-2014    Sex      Female         14
# 4     Suicide        Humboldt  2012-2014    Sex      Female         28
# ..        ...             ...        ...    ...         ...        ...
# 114   Suicide    Contra Costa  2012-2014    Sex       Total        318
# 115   Suicide     Los Angeles  2012-2014    Sex       Total       2327
# 116   Suicide          Solano  2012-2014    Sex       Total        149
# 117   Suicide      Santa Cruz  2012-2014    Sex       Total        120
# 118   Suicide          Sonoma  2012-2014    Sex       Total        196
#
#      Denominator    Rate  Age Adjusted Rate
# 0        3159000   3.260              3.268
# 1         394300   4.565              4.697
# 2         132000   9.849              9.317
# 3         148700   9.414              7.830
# 4         201500  13.900             12.980
# ..           ...     ...                ...
# 114      3268000   9.730              9.341
# 115     30170000   7.713              7.520
# 116      1264000  11.790             11.170
# 117       809800  14.820             14.590
# 118      1482000  13.220             11.790
#
# [119 rows x 9 columns]

# %% [markdown]
# ### Counties - Sex - "2015-2017"

# %%
count_sex_by15_17 = suicide_county_sex['Year'] == '2015-2017'
count_sex_15_17 = suicide_county_sex[count_sex_by15_17]
count_sex_15_17 = count_sex_15_17.reset_index()
count_sex_15_17 = count_sex_15_17.drop(columns=['index'])
count_sex_15_17
# Out:
#     Indicator       Geography       Year Strata Strata Name  Numerator  \
# 0     Suicide    Contra Costa  2015-2017    Sex      Female         87
# 1     Suicide  San Bernardino  2015-2017    Sex      Female        150
# 2     Suicide          Shasta  2015-2017    Sex      Female         31
# 3     Suicide        Humboldt  2015-2017    Sex      Female         26
# 4     Suicide          Merced  2015-2017    Sex      Female         22
# ..        ...             ...        ...    ...         ...        ...
# 117   Suicide           Butte  2015-2017    Sex       Total        128
# 118   Suicide      Santa Cruz  2015-2017    Sex       Total        136
# 119   Suicide          Sonoma  2015-2017    Sex       Total        205
# 120   Suicide         Trinity  2015-2017    Sex       Total         16
# 121   Suicide          Sutter  2015-2017    Sex       Total         42
#
#      Denominator    Rate  Age Adjusted Rate
# 0        1733000   5.021              4.779
# 1        3243000   4.626              4.691
# 2         272400  11.380             10.240
# 3         203300  12.790             12.520
# 4         405600   5.424              5.810
# ..           ...     ...                ...
# 117       676000  18.940             18.310
# 118       829300  16.400             15.740
# 119      1512000  13.550             12.190
# 120        40490  39.510             43.870
# 121       294800  14.250             13.870
#
# [122 rows x 9 columns]

# %% [markdown]
# ## Counties - Race

# %%
county_byrace = suicide_counties['Strata'] == 'Race/Ethnicity'
suicide_county_race = suicide_counties[county_byrace]
suicide_county_race = suicide_county_race.reset_index()
suicide_county_race = suicide_county_race.drop(columns=['index'])
suicide_county_race
# Out:
#     Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0     Suicide   Alameda  2000-2002  Race/Ethnicity    Asian-NH         47
# 1     Suicide   Alameda  2000-2002  Race/Ethnicity    Black-NH         34
# 2     Suicide   Alameda  2000-2002  Race/Ethnicity        Hisp         31
# 3     Suicide   Alameda  2000-2002  Race/Ethnicity    White-NH        234
# 4     Suicide   Alameda  2003-2005  Race/Ethnicity    Asian-NH         46
# ..        ...       ...        ...             ...         ...        ...
# 573   Suicide      Yolo  2015-2017  Race/Ethnicity    White-NH         54
# 574   Suicide      Yuba  2006-2008  Race/Ethnicity    White-NH         35
# 575   Suicide      Yuba  2009-2011  Race/Ethnicity    White-NH         24
# 576   Suicide      Yuba  2012-2014  Race/Ethnicity    White-NH         27
# 577   Suicide      Yuba  2015-2017  Race/Ethnicity    White-NH         33
#
#      Denominator    Rate  Age Adjusted Rate
# 0         970100   4.845              4.940
# 1         622600   5.461              5.596
# 2         858900   3.609              4.775
# 3        1757000  13.320             11.890
# 4        1028000   4.473              4.353
# ..           ...     ...                ...
# 573       309100  17.470             15.910
# 574       128900  27.150             25.060
# 575       128200  18.720             17.630
# 576       129900  20.780             19.950
# 577       131500  25.100             23.100
#
# [578 rows x 9 columns]

# %% [markdown]
# ### Counties - Race - "2000-2002"

# %%
count_race_by00_02 = suicide_county_race['Year'] == '2000-2002'
count_race_00_02 = suicide_county_race[count_race_by00_02]
count_race_00_02 = count_race_00_02.reset_index()
count_race_00_02 = count_race_00_02.drop(columns=['index'])
count_race_00_02
# Out:
#    Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0    Suicide   Alameda  2000-2002  Race/Ethnicity    Asian-NH         47
# 1    Suicide   Alameda  2000-2002  Race/Ethnicity    Black-NH         34
# 2    Suicide   Alameda  2000-2002  Race/Ethnicity        Hisp         31
# 3    Suicide   Alameda  2000-2002  Race/Ethnicity    White-NH        234
# 4    Suicide    Amador  2000-2002  Race/Ethnicity    White-NH         17
# ..       ...       ...        ...             ...         ...        ...
# 83   Suicide    Tulare  2000-2002  Race/Ethnicity    White-NH         56
# 84   Suicide  Tuolumne  2000-2002  Race/Ethnicity    White-NH         28
# 85   Suicide   Ventura  2000-2002  Race/Ethnicity        Hisp         35
# 86   Suicide   Ventura  2000-2002  Race/Ethnicity    White-NH        161
# 87   Suicide      Yolo  2000-2002  Race/Ethnicity    White-NH         41
#
#     Denominator    Rate  Age Adjusted Rate
# 0        970100   4.845              4.940
# 1        622600   5.461              5.596
# 2        858900   3.609              4.775
# 3       1757000  13.320             11.890
# 4         88520  19.200             20.070
# ..          ...     ...                ...
# 83       456700  12.260             11.270
# 84       140600  19.920             18.580
# 85       799400   4.378              5.437
# 86      1281000  12.570             11.710
# 87       297900  13.760             13.510
#
# [88 rows x 9 columns]

# %% [markdown]
# ### Counties - Race - "2003-2005"

# %%
count_race_by03_05 = suicide_county_race['Year'] == '2003-2005'
count_race_03_05 = suicide_county_race[count_race_by03_05]
count_race_03_05 = count_race_03_05.reset_index()
count_race_03_05 = count_race_03_05.drop(columns=['index'])
count_race_03_05
# Out:
#    Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0    Suicide   Alameda  2003-2005  Race/Ethnicity    Asian-NH         46
# 1    Suicide   Alameda  2003-2005  Race/Ethnicity    Black-NH         36
# 2    Suicide   Alameda  2003-2005  Race/Ethnicity        Hisp         44
# 3    Suicide   Alameda  2003-2005  Race/Ethnicity    White-NH        213
# 4    Suicide     Butte  2003-2005  Race/Ethnicity    White-NH        104
# ..       ...       ...        ...             ...         ...        ...
# 83   Suicide    Tulare  2003-2005  Race/Ethnicity    White-NH         58
# 84   Suicide  Tuolumne  2003-2005  Race/Ethnicity    White-NH         38
# 85   Suicide   Ventura  2003-2005  Race/Ethnicity        Hisp         37
# 86   Suicide   Ventura  2003-2005  Race/Ethnicity    White-NH        171
# 87   Suicide      Yolo  2003-2005  Race/Ethnicity    White-NH         35
#
#     Denominator    Rate  Age Adjusted Rate
# 0       1028000   4.473              4.353
# 1        596200   6.038              6.004
# 2        903100   4.872              5.719
# 3       1677000  12.700             10.980
# 4        500500  20.780             19.770
# ..          ...     ...                ...
# 83       455700  12.730             12.060
# 84       142200  26.710             25.750
# 85       865900   4.273              4.763
# 86      1276000  13.400             12.190
# 87       300100  11.660             11.410
#
# [88 rows x 9 columns]

# %% [markdown]
# ### Counties - Race - "2006-2008"

# %%
count_race_by06_08 = suicide_county_race['Year'] == '2006-2008'
count_race_06_08 = suicide_county_race[count_race_by06_08]
count_race_06_08 = count_race_06_08.reset_index()
count_race_06_08 = count_race_06_08.drop(columns=['index'])
count_race_06_08
# Out:
#    Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0    Suicide   Alameda  2006-2008  Race/Ethnicity    Asian-NH         53
# 1    Suicide   Alameda  2006-2008  Race/Ethnicity    Black-NH         30
# 2    Suicide   Alameda  2006-2008  Race/Ethnicity        Hisp         34
# 3    Suicide   Alameda  2006-2008  Race/Ethnicity    Multi-NH         14
# 4    Suicide   Alameda  2006-2008  Race/Ethnicity    White-NH        217
# ..       ...       ...        ...             ...         ...        ...
# 86   Suicide    Tulare  2006-2008  Race/Ethnicity    White-NH         76
# 87   Suicide   Ventura  2006-2008  Race/Ethnicity        Hisp         42
# 88   Suicide   Ventura  2006-2008  Race/Ethnicity    White-NH        205
# 89   Suicide      Yolo  2006-2008  Race/Ethnicity    White-NH         45
# 90   Suicide      Yuba  2006-2008  Race/Ethnicity    White-NH         35
#
#     Denominator    Rate  Age Adjusted Rate
# 0       1093000   4.851              4.842
# 1        576200   5.206              5.035
# 2        950000   3.579              5.170
# 3        154100   9.082             13.710
# 4       1613000  13.450             11.380
# ..          ...     ...                ...
# 86       452200  16.800             15.050
# 87       922000   4.555              5.084
# 88      1246000  16.450             14.550
# 89       303900  14.810             14.040
# 90       128900  27.150             25.060
#
# [91 rows x 9 columns]

# %% [markdown]
# ### Counties - Race - "2009-2011"

# %%
count_race_by09_11 = suicide_county_race['Year'] == '2009-2011'
count_race_09_11 = suicide_county_race[count_race_by09_11]
count_race_09_11 = count_race_09_11.reset_index()
count_race_09_11 = count_race_09_11.drop(columns=['index'])
count_race_09_11
# Out:
#    Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0    Suicide   Alameda  2009-2011  Race/Ethnicity    Asian-NH         59
# 1    Suicide   Alameda  2009-2011  Race/Ethnicity    Black-NH         40
# 2    Suicide   Alameda  2009-2011  Race/Ethnicity        Hisp         57
# 3    Suicide   Alameda  2009-2011  Race/Ethnicity    White-NH        242
# 4    Suicide    Amador  2009-2011  Race/Ethnicity    White-NH         30
# ..       ...       ...        ...             ...         ...        ...
# 92   Suicide  Tuolumne  2009-2011  Race/Ethnicity    White-NH         37
# 93   Suicide   Ventura  2009-2011  Race/Ethnicity        Hisp         37
# 94   Suicide   Ventura  2009-2011  Race/Ethnicity    White-NH        230
# 95   Suicide      Yolo  2009-2011  Race/Ethnicity    White-NH         34
# 96   Suicide      Yuba  2009-2011  Race/Ethnicity    White-NH         24
#
#     Denominator    Rate  Age Adjusted Rate
# 0       1180000   5.001              4.994
# 1        561000   7.130              6.849
# 2       1024000   5.564              6.107
# 3       1564000  15.470             12.870
# 4         90840  33.020             25.790
# ..          ...     ...                ...
# 92       136300  27.150             25.470
# 93       995700   3.716              4.222
# 94      1211000  18.990             16.310
# 95       303900  11.190             10.040
# 96       128200  18.720             17.630
#
# [97 rows x 9 columns]

# %% [markdown]
# ### Counties - Race - "2012-2014"

# %%
count_race_by12_14 = suicide_county_race['Year'] == '2012-2014'
count_race_12_14 = suicide_county_race[count_race_by12_14]
count_race_12_14 = count_race_12_14.reset_index()
count_race_12_14 = count_race_12_14.drop(columns=['index'])
count_race_12_14
# Out:
#     Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0     Suicide   Alameda  2012-2014  Race/Ethnicity    Asian-NH         84
# 1     Suicide   Alameda  2012-2014  Race/Ethnicity    Black-NH         35
# 2     Suicide   Alameda  2012-2014  Race/Ethnicity        Hisp         43
# 3     Suicide   Alameda  2012-2014  Race/Ethnicity    White-NH        260
# 4     Suicide    Amador  2012-2014  Race/Ethnicity    White-NH         33
# ..        ...       ...        ...             ...         ...        ...
# 98    Suicide   Ventura  2012-2014  Race/Ethnicity    Asian-NH         15
# 99    Suicide   Ventura  2012-2014  Race/Ethnicity        Hisp         49
# 100   Suicide   Ventura  2012-2014  Race/Ethnicity    White-NH        220
# 101   Suicide      Yolo  2012-2014  Race/Ethnicity    White-NH         39
# 102   Suicide      Yuba  2012-2014  Race/Ethnicity    White-NH         27
#
#      Denominator    Rate  Age Adjusted Rate
# 0        1259000   6.671              6.343
# 1         564700   6.198              5.993
# 2        1087000   3.957              4.007
# 3        1579000  16.460             14.440
# 4          88660  37.220             29.320
# ..           ...     ...                ...
# 98        166600   9.006              8.635
# 99       1048000   4.678              4.871
# 100      1203000  18.280             15.740
# 101       306000  12.740             11.720
# 102       129900  20.780             19.950
#
# [103 rows x 9 columns]

# %% [markdown]
# ### Counties - Race - "2015-2017"

# %%
count_race_by15_17 = suicide_county_race['Year'] == '2015-2017'
count_race_15_17 = suicide_county_race[count_race_by15_17]
count_race_15_17 = count_race_15_17.reset_index()
count_race_15_17 = count_race_15_17.drop(columns=['index'])
count_race_15_17
# Out:
#     Indicator Geography       Year          Strata Strata Name  Numerator  \
# 0     Suicide   Alameda  2015-2017  Race/Ethnicity    Asian-NH         82
# 1     Suicide   Alameda  2015-2017  Race/Ethnicity    Black-NH         41
# 2     Suicide   Alameda  2015-2017  Race/Ethnicity        Hisp         60
# 3     Suicide   Alameda  2015-2017  Race/Ethnicity    White-NH        247
# 4     Suicide     Butte  2015-2017  Race/Ethnicity    White-NH        112
# ..        ...       ...        ...             ...         ...        ...
# 106   Suicide   Ventura  2015-2017  Race/Ethnicity        Hisp         39
# 107   Suicide   Ventura  2015-2017  Race/Ethnicity    White-NH        230
# 108   Suicide      Yolo  2015-2017  Race/Ethnicity        Hisp         16
# 109   Suicide      Yolo  2015-2017  Race/Ethnicity    White-NH         54
# 110   Suicide      Yuba  2015-2017  Race/Ethnicity    White-NH         33
#
#      Denominator    Rate  Age Adjusted Rate
# 0        1338000   6.130              5.953
# 1         567200   7.228              7.083
# 2        1145000   5.242              5.794
# 3        1589000  15.550             13.310
# 4         500000  22.400             19.910
# ..           ...     ...                ...
# 106      1091000   3.576              3.577
# 107      1191000  19.310             16.450
# 108       203500   7.862              8.807
# 109       309100  17.470             15.910
# 110       131500  25.100             23.100
#
# [111 rows x 9 columns]
